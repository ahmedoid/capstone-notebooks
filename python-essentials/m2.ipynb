# %% [markdown]
# # مختبر المتغيرات والأنواع (Variables and Types)

# %% [markdown]
# في هذا المختبر ستتدرب على تعريف المتغيرات (Variables) واستكشاف الأنواع الأساسية (int, float, str) وإجراء العمليات الحسابية والتحويل بين الأنواع. أكمل تعليمات TODO في كل خلية كود.

# %% [markdown]
# ## التمرين 1: تعريف المتغيرات (Assigning Variables)
#
# قم بتعريف المتغيرات التالية:
# - price (سعر منتج): عدد عشري (float) قيمته 19.99
# - quantity (الكمية): عدد صحيح (int) قيمته 7
# - product (اسم المنتج): نص (str) قيمته "كتاب"
# ثم اطبع قيمة كل متغير باستخدام الدالة print.

# %%
# TODO: عرف المتغيرات price, quantity, product بقيم مناسبة

# TODO: اطبع كل متغير على سطر منفصل

# %% [markdown]
# ## التمرين 2: استكشاف الأنواع (Exploring Types)
#
# استخدم الدالة type() لاستعراض أنواع المتغيرات التي عرفتها في التمرين السابق.

# %%
# TODO: اطبع نوع المتغير price
# TODO: اطبع نوع المتغير quantity
# TODO: اطبع نوع المتغير product

# %% [markdown]
# ## التمرين 3: العمليات الحسابية على المتغيرات (Arithmetic Operations)
#
# لديك متغيران a = 15 و b = 4. قم بحساب وإسناد ثم طباعة:
# - مجموع a و b
# - الفرق بين a و b
# - حاصل ضرب a في b
# - خارج قسمة a على b
# - خارج القسمة الصحيح (integer division) a // b
# - باقي القسمة a % b
# - أُس a مرفوعاً إلى b

# %%
a = 15
b = 4

# TODO: احسب واسند المجموع إلى sum_ab ثم اطبع
# TODO: احسب واسند الفرق إلى diff_ab ثم اطبع
# TODO: احسب واسند حاصل الضرب إلى prod_ab ثم اطبع
# TODO: احسب واسند خارج القسمة إلى div_ab ثم اطبع
# TODO: احسب واسند خارج القسمة الصحيح إلى int_div_ab ثم اطبع
# TODO: احسب واسند باقي القسمة إلى mod_ab ثم اطبع
# TODO: احسب واسند الأُس إلى pow_ab ثم اطبع

# %% [markdown]
# ## التمرين 4: التحويل بين الأنواع (Type Conversion)
#
# لديك النص num_str = "3.14" (يمثل عدداً عشرياً) والعدد الصحيح quantity = 5. قم بـ:
# - تحويل num_str إلى float وخزنه في num_float
# - تحويل quantity إلى float وخزنه في quantity_float
# - تحويل quantity إلى string وخزنه في quantity_str
# - تحويل num_float إلى int وخزنه في num_int
# ثم اطبع الأنواع الجديدة للتأكد.

# %%
num_str = "3.14"
quantity = 5

# TODO: حول num_str إلى float واسنده إلى num_float
# TODO: حول quantity إلى float واسنده إلى quantity_float
# TODO: حول quantity إلى str واسنده إلى quantity_str
# TODO: حول num_float إلى int واسنده إلى num_int

# TODO: اطبع نوع وقيمة num_float
# TODO: اطبع نوع وقيمة quantity_float
# TODO: اطبع نوع وقيمة quantity_str
# TODO: اطبع نوع وقيمة num_int

# %% [markdown]
# ## التمرين 5: تنسيق النصوص مع المتغيرات (String Formatting)
#
# باستخدام متغيرات التمرين الأول (price, quantity, product)، قم بحساب السعر الإجمالي (total_price = price * quantity) ثم اطبع رسالة نصية تحتوي على اسم المنتج والكمية والسعر الإجمالي بتنسيق مناسب. استخدم f-string.

# %%
# لنعد استخدام المتغيرات (قد تحتاج لتشغيل خلية التمرين 1 أولاً)
# إذا لم تكن المتغيرات معرفة، قم بتعريفها من جديد:
price = 19.99
quantity = 7
product = "كتاب"

# TODO: احسب total_price = price * quantity
# TODO: اطبع باستخدام f-string: "سعر {product}: {price} جنيه، الكمية: {quantity}، الإجمالي: {total_price} جنيه"

# %% [markdown]
# ## التمرين 6: آلة حاسبة بسيطة (Simple Calculator)
#
# في هذا التمرين، ستقوم ببناء آلة حاسبة باستخدام متغيرين x = 20 و y = 6، وطبق العمليات الأربع الأساسية (جمع، طرح، ضرب، قسمة) مع طباعة الناتج بصيغة واضحة.

# %%
x = 20
y = 6

# TODO: احسب sum_xy, sub_xy, mul_xy, div_xy
# TODO: اطبع "ناتج جمع {} + {} = {}" وهكذا لباقي العمليات

# %% [markdown]
# ## خلاصة
#
# لقد قمت في هذا المختبر بتطبيق أساسيات المتغيرات والأنواع في بايثون. تأكد من أنك تفهم طريقة الإسناد، استكشاف الأنواع، العمليات الحسابية الأساسية، والتحويل بين الأنواع. هذه المفاهيم هي حجر الزاوية لأي برنامج.
