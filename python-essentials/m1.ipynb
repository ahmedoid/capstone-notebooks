# %% [markdown]
# # مختبر أساسيات بايثون: الطباعة والتعليقات
#
# في هذا المختبر، ستكتب أولى برامجك باستخدام دالة `print()` لعرض النصوص والأعداد، وستتعلم كيفية إضافة التعليقات (comments) لتوضيح الكود. اتبع التعليمات في كل خلية وأكمل المهام المطلوبة (عليها علامة TODO).

# %% [markdown]
# ## مقدمة عن بايثون
# بايثون هي لغة برمجة عالية المستوى، سهلة التعلم، وتستخدم في تطوير الويب، تحليل البيانات، الذكاء الاصطناعي، والمزيد. تتميز ببناء جملة بسيط وواضح.

# %% [markdown]
# ## دالة `print()`
# تستخدم دالة `print()` لعرض محتوى على الشاشة، سواء نصوصًا (سلاسل نصية - strings) أو أعدادًا أو نتائج عمليات حسابية. ضع ما تريد عرضه بين الأقواس. مثال: `print('مرحباً!')`.

# %%
# طباعة ترحيب
print('Hello, World!')
# TODO: اكتب أمر print آخر يطبع 'Welcome to Python!'

# %%
# عرض نتيجة عملية جمع
print('Sum:', 2 + 3)
# TODO: اطبع حاصل ضرب 4 و 5

# %% [markdown]
# ## التعليقات (Comments)
# التعليق هو نص يكتب في الكود لتوضيحه أو لترك ملاحظات. في بايثون، يبدأ التعليق برمز `#` ولا ينفذه المفسر. التعليقات مهمة لتنظيم الكود وجعله مفهوماً للآخرين.

# %%
# TODO: أضف تعليقاً فوق السطر التالي يوضح ما يفعله
print('Python programming')

# %%
# TODO: اكتب برنامجاً صغيراً:
# 1- اطبع اسمك
# 2- اكتب تعليقاً يحوي تاريخ اليوم
# 3- اطبع لونك المفضل

# %% [markdown]
# ## تدريب شامل
# اكتب برنامجاً يطبع ثلاثة أسطر: اسمك، عمرك، وهوايتك. أضف تعليقاً يصف البرنامج.

# %%
# TODO: اكتب الكود المطلوب

# %% [markdown]
# ## مبروك! لقد أكملت المختبر
# لقد تعلمت كيفية استخدام دالة `print()` لعرض المخرجات، وإضافة التعليقات لتوثيق الكود. يمكنك الآن كتابة برامج بسيطة بلغة بايثون.
