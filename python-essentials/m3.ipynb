# %% [markdown]
# # مختبر الجمل الشرطية (Conditional Statements)
#
# في هذا المختبر، ستتعلم كيفية استخدام الجمل الشرطية في بايثون لاتخاذ القرارات. ستتدرب على `if`, `else`, `elif`، ودمج الشروط باستخدام `and` و `or`. ستقوم أيضًا ببناء محاكي نظام درجات (Grading System) بسيط.
#
# لنبدأ!

# %% [markdown]
# ## تذكير سريع
#
# - `if condition:` ... `elif condition:` ... `else:`: تسمح بتنفيذ كود بناءً على شرط.
# - عوامل المقارنة: `==`, `!=`, `>`, `<`, `>=`, `<=`
# - العوامل المنطقية: `and` (كلاهما صحيح), `or` (أحدهما صحيح)
# - الكود داخل الكتل يجب أن يكون مسبوقًا بمسافة بادئة (indentation).

# %%
# TODO: عيّن قيمة للمتغير x يساوي 7. ثم اكتب جملة if تطبع "x أكبر من 5" إذا كان x > 5.
x = 7

# %%
# TODO: اكتب برنامجًا يتحقق مما إذا كان العدد `num` زوجيًا (even) أم لا.
# إذا كان زوجيًا اطبع "زوجي"، وإلا اطبع "فردي".
num = 24
# TODO: اكتب جملة if/else هنا

# %%
# TODO: اكتب نظام تصنيف درجات بسيط جدًا:
# إذا كانت score >= 90، اطبع "A"
# إذا كانت score >= 80 (وأقل من 90)، اطبع "B"
# إذا كانت score >= 70، اطبع "C"
# غير ذلك اطبع "F"
score = 85
# TODO: استخدم if/elif/else

# %% [markdown]
# ## دمج الشروط بـ `and` و `or`
#
# - `and`: يتحقق من أن جميع الشروط صحيحة.
# - `or`: يتحقق من أن أحد الشروط على الأقل صحيح.
#
# مثال: `if age >= 18 and has_ticket:`.

# %%
# TODO: تحقق من أن temperature بين 20 و 30 (شامل) باستخدام and. اطبع "درجة الحرارة مناسبة" إن تحقق الشرط.
temperature = 25
# TODO: اكتب شرط and

# %%
# TODO: تحقق مما إذا كان day هو "Saturday" أو "Sunday" باستخدام or. اطبع "عطلة نهاية الأسبوع" إذا كان كذلك.
day = "Sunday"
# TODO: اكتب شرط or

# %% [markdown]
# ## تطبيق: محاكي نظام الدرجات (Grading System)
#
# سنكمل الآن بناء نظام يصنف الدرجة إلى تقدير حسب النطاقات التالية:
#
# - 90-100: A
# - 80-89: B
# - 70-79: C
# - 60-69: D
# - أقل من 60: F
#
# سنستخدم دالة لتطبيق هذه الشروط على مجموعة درجات.

# %%
import numpy as np
np.random.seed(42)

# TODO: املأ الدالة grading(score) بحيث تعيد التقدير المناسب بناءً على النطاقات أعلاه.
def grading(score):
    # TODO: اكتب سلسلة if/elif/else لتصنيف الدرجة
    pass

# %%
# توليد 10 درجات عشوائية بين 0 و 100
scores = np.random.randint(0, 101, size=10)
print("الدرجات:", scores)

# TODO: استخدم list comprehension أو حلقة for لتطبيق الدالة grading على كل درجة وطبع النتيجة.
# قم بتخزين التقديرات في قائمة grades.

# %% [markdown]
# ## ممتاز! لقد تدربت على:
#
# - كتابة جمل if, else, elif.
# - استخدام and و or لدمج الشروط.
# - بناء محاكي نظام درجات.
#
# استمر في التمرن لمزيد من الإتقان.
