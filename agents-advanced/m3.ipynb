# %% [markdown]
# # مقدمة
# مرحبًا بك في مختبر الأنظمة متعددة الوكلاء. ستقوم في هذا الدفتر بتطبيق مفاهيم التواصل والتنسيق بين الوكلاء من خلال بناء محاكاة بسيطة لموجه رسائل وتنسيق مهام بين وكلاء متخصصين.

# %% [markdown]
# ## مفهوم الأنظمة متعددة الوكلاء (Multi-Agent Systems)
# في الأنظمة المتعددة الوكلاء، يتم توزيع المهام على عدة وكلاء متخصصين يتعاونون لتحقيق هدف مشترك. كل وكيل له دور محدد (مخطط، منفذ، ناقد) ويتواصل مع الآخرين عبر رسائل. هذا الأسلوب يحسن الكفاءة وقابلية التوسع.

# %% [markdown]
# ## بروتوكولات الاتصال والأدوار (Communication & Roles)
# يحتاج الوكلاء إلى بروتوكول واضح لتبادل الرسائل. يحدد كل وكيل بدور:
# - **مخطط (Planner)**: يقسم المهام ويعينها.
# - **منفذ (Executor)**: ينفذ المهام ويعيد النتائج.
# - **ناقد (Critic)**: يراجع النتائج ويقدم تغذية راجعة.
# سنبني دالة توجيه رسائل (Message Router) ترسل الرسالة إلى الوكيل المناسب حسب الدور.

# %%
class Agent:
    def __init__(self, name, role):
        # TODO: قم بتخزين name و role كخاصيتين (self.name, self.role)
        pass

    def process_message(self, message):
        # TODO: اطبع رسالة استلام (مثال: print(f'{self.name} received: {message}')) ثم أعد رداً مثل '{self.role} processed: {message}'
        pass

# %%
# إنشاء نسخ من الوكلاء
planner = Agent('Planner1', 'planner')
executor = Agent('Executor1', 'executor')
critic = Agent('Critic1', 'critic')
# قاموس يربط الدور بالوكيل
agents_dict = {
    'planner': planner,
    'executor': executor,
    'critic': critic
}
print('تم إنشاء قاموس الوكلاء:')
for role, agent in agents_dict.items():
    print(f'{role}: {agent.name}')

# %% [markdown]
# ## موجه الرسائل (Message Router)
# الآن سنبني دالة `route_message` التي تستقبل رسالة ودور الوكيل المستهدف، ثم تبحث في قاموس الوكلاء عن وكيل بهذا الدور وترسل له الرسالة.

# %%
def route_message(agents_dict, target_role, message):
    # TODO: تحقق مما إذا كان target_role موجوداً في agents_dict. إذا كان موجوداً، استدعِ process_message للوكيل وأعد النتيجة. وإلا، أعد رسالة خطأ.
    pass

# %%
# اختبار موجه الرسائل
print(route_message(agents_dict, 'planner', 'Plan next task'))
print(route_message(agents_dict, 'executor', 'Execute task A'))
print(route_message(agents_dict, 'critic', 'Review task A result'))
print(route_message(agents_dict, 'unknown', 'Some message'))

# %% [markdown]
# ## تنسيق بسيط بين الوكلاء (Simple Agent Coordination)
# لمحاكاة تنسيق بسيط، سنقوم بإنشاء دالة `coordinate_task` التي تأخذ مهمة من وكيل المخطط، ترسلها إلى المنفذ، ثم ترسل النتيجة إلى الناقد للحصول على تغذية راجعة.

# %%
def coordinate_task(agents_dict, task):
    # TODO: استخدم route_message لإرسال المهمة إلى 'planner' (للحصول على خطة)، ثم أرسل الخطة إلى 'executor' (للتنفيذ)، ثم أرسل نتيجة التنفيذ إلى 'critic' (للحصول على مراجعة). أعد المراجعة النهائية.
    pass

# %%
# اختبار تنسيق المهام
final_feedback = coordinate_task(agents_dict, 'Build a web app')
print('Final feedback:', final_feedback)
