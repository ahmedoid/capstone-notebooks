# %% [markdown]
# # مختبر: مقدمة عن التعابير النمطية
#
# في هذا الدفتر، سنستكشف أساسيات التعابير النمطية (`Regex`) باستخدام بايثون.
#
# المكتبات المطلوبة:
# - `re` (مضمنة)
#
# لنبدأ!

# %%
import re
import numpy as np
np.random.seed(42)
# نص عينة يحتوي على كلمات وأرقام لاستخدامها في التمارين
text = "The quick brown fox jumps over the lazy dog. cat cot cut cbt c.t c?t c t 42 123 3.14 99.99 1000 0.5"
print("النص العينة:\n", text)

# %% [markdown]
# ## المطابقة الحرفية (Literal Matching)
#
# المطابقة الحرفية تبحث عن تطابق تام لنمط معين. على سبيل المثال، `re.findall(r'fox', text)` يعيد قائمة بكل تواجدات كلمة "fox".
#
# **ملاحظة**: الدالة `re.findall()` تعيد قائمة بالتواجدات.

# %%
# TODO: استخدم re.findall للبحث عن كلمة "fox" في النص، واحفظ النتيجة في متغير matches
matches = ...
print("عدد تواجدات 'fox':", len(matches))

# %% [markdown]
# ## النقطة `.` - مطابقة أي محرف
#
# الرمز `.` في التعابير النمطية يطابق أي محرف واحد (ماعدا سطر جديد عادةً). مثلاً `c.t` يطابق "cat"، "cot"، "cbt"، لكن لا يطابق "ct".
#
# التعبير `c.t` يبحث عن أي ثلاثة أحرف تبدأ بـ `c` وتنتهي بـ `t` وفي الوسط أي محرف.

# %%
# TODO: استخدم تعبيرًا نمطيًا بالنقطة للعثور على كل الكلمات من الشكل "c.t" (أي حرف بين c و t). استخدم re.findall.
dot_matches = ...
print("الكلمات التي تطابق 'c.t':", dot_matches)

# %% [markdown]
# ## أصناف المحارف (Character Classes)
#
# أصناف المحارف تسمح بتحديد مجموعة من المحارف الممكنة في موقع معين. توضع بين قوسين مربعين `[]`. أمثلة:
# - `[aeiou]` يطابق أي حرف صوتي صغير.
# - `[0-9]` يطابق أي رقم.
# - `[a-zA-Z]` يطابق أي حرف إنجليزي كبير أو صغير.
#
# هناك أصناف مختصرة مثل `\d` (رقم)، `\w` (حرف أو رقم أو _)، `\s` (فراغ).

# %%
# TODO: استخدم re.findall مع تعبير نمطي لمطابقة الأرقام (digits) في النص. استخدم [0-9] أو \d.
digits = ...
print("الأرقام الموجودة:", digits)

# %% [markdown]
# ## تمرين: البحث عن الأرقام في النص
#
# الآن سنبحث عن الأرقام الكاملة (مثل 42، 3.14) وليس مجرد أحرف رقمية منفردة. يجب أن يلتقط النمط الأرقام الصحيحة والعشرية. فكر في استخدام `\d+` لأرقام صحيحة، وإضافة جزء `\.\d+` اختياري للأرقام العشرية.

# %%
# TODO: اكتب تعبيرًا نمطيًا يطابق الأرقام الصحيحة والعشرية (مثل 42, 3.14). استخدم re.findall.
numbers = ...
print("الأرقام الكاملة:", numbers)

# %% [markdown]
# ## خلاصة
#
# في هذا المختبر تعلمت:
# - استخدام `re.findall`.
# - المطابقة الحرفية.
# - استخدام النقطة `.`.
# - أصناف المحارف `[]` والمختصرات `\d`.
# - تركيب تعابير للأرقام الكاملة.
#
# التعابير النمطية أداة قوية، استمر في التمرن!
