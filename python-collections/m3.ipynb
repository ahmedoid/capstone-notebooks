# %% [markdown]
# # مختبر الدوال الأساسية
#
# في هذا المختبر ستطبق مفاهيم الدوال في بايثون: تعريف الدوال واستدعائها، تمرير الوسائط، إرجاع القيم، الوسائط الافتراضية، ونطاق المتغيرات. ستقوم بكتابة كود لإكمال الدوال الناقصة واختبارها.

# %% [markdown]
# ## التمرين 1: تعريف دالة واستدعاؤها (def)
#
# أكمل الدالة التالية `greet()` لتأخذ اسمًا (name) وتطبع تحية. ثم استدعِ الدالة باسم "أحمد".

# %%
def greet(name):
    # TODO: أكمل تعريف الدالة greet التي تأخذ name وتطبع "مرحبًا، {name}!"
    # اكتب جسم الدالة هنا

# TODO: استدعِ الدالة greet مع الاسم "أحمد"

# %% [markdown]
# ## التمرين 2: الوسائط وإرجاع القيم (return)
#
# أكمل الدالة `sum_numbers` لتأخذ عددين وتعيد مجموعهما. ثم اختبرها بطباعة النتيجة.

# %%
def sum_numbers(a, b):
    pass  # TODO: استبدل السطر بـ return a+b

# TODO: استدعِ الدالة مع 5 و 7 واطبع الناتج

# %% [markdown]
# ## التمرين 3: الوسائط الافتراضية (Default Arguments)
#
# أكمل الدالة `power` التي تأخذ base و exponent مع قيمة افتراضية exponent=2، وتعيد base مرفوعة للأس. ثم جربها بمعطى واحد ومعطيين.

# %%
def power(base, exponent=2):
    # TODO: اكتب جسم الدالة هنا لترجع base**exponent

# TODO: اختبر الدالة بطباعة power(3) و power(2,3)

# %% [markdown]
# ## التمرين 4: نطاق المتغيرات (Scope)
#
# المتغير `score` أدناه خارج الدالة. في الكود الموجود، هناك محاولة لتعديله داخل الدالة لكنها فشلت. أصلح الكود ليصبح التعديل صحيحًا باستخدام `global` ثم اطبع النتيجة.

# %%
score = 50  # متغير عام

def update_score():
    # TODO: استخدم global للوصول إلى score ثم زده بمقدار 10
    # أكمل الكود
    print("Score inside:", score)

update_score()
# TODO: اطبع score خارج الدالة للتأكد من تغيره
print("Score outside:", score)

# %% [markdown]
# ## تطبيق: مجموعة أدوات حسابية بالدوال
#
# الآن ستكتب عدة دوال مفيدة وتستخدمها مع بيانات مولدة. استخدم البذرة `np.random.seed(42)` لتوليد الأرقام.

# %%
import numpy as np

# توليد قائمة عشوائية من 10 أعداد صحيحة بين 1 و 100
np.random.seed(42)
data = np.random.randint(1, 101, size=10).tolist()
print("البيانات:", data)

# TODO: أكمل دالة average التي تأخذ قائمة من الأعداد وتعيد متوسطها
def average(lst):
    # احسب المتوسط وارده

# TODO: أكمل دالة minimum التي تعيد أصغر عنصر في القائمة
def minimum(lst):
    # استخدم min

# TODO: أكمل دالة maximum التي تعيد أكبر عنصر
def maximum(lst):
    # استخدم max

# TODO: اختبر الدوال على data واطبع النتائج
print("المتوسط:", average(data))
print("الأصغر:", minimum(data))
print("الأكبر:", maximum(data))

# %% [markdown]
# ## دوال إضافية (اختياري)
#
# إذا أتممت السابق، اكتب دالة `describe` تأخذ قائمة وتطبع المتوسط والأصغر والأكبر. استخدم الدوال السابقة داخل `describe`.

# %%
# TODO: أكمل دالة describe التي تستخدم average, minimum, maximum
def describe(lst):
    # اطبع المتوسط، الأصغر، الأكبر
    pass  # استبدل بالكود

describe(data)
