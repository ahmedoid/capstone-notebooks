# %% [markdown]
# # مختبر: الحلقات التكرارية في بايثون
#
# في هذا المختبر، ستطبّق مفاهيم الحلقات التكرارية (Loops) في بايثون. عليك إكمال كل خلية كود تحتوي على تعليق `# TODO` بكتابة التعليمات المناسبة. البيانات المستخدمة مولَّدة داخل الدفتر باستخدام `numpy`.

# %%
import numpy as np
np.random.seed(42)
numbers = np.random.randint(1, 100, 20).tolist()  # 20 عددًا عشوائيًا بين 1 و 99
names = ['Ali', 'Sara', 'Ahmed', 'Mona', 'Khalid', 'Nora', 'Omar']
print("الأعداد:", numbers)
print("الأسماء:", names)

# %% [markdown]
# ## التكرار بعدد محدد باستخدام `for`
#
# استخدم حلقة `for` مع الدالة `range` لطباعة الأعداد الصحيحة من 1 إلى 10.

# %%
# TODO: اكتب حلقة for تطبع الأعداد من 1 إلى 10 (شاملة)

# %% [markdown]
# ## التكرار عبر قائمة (List)
#
# لتكن لديك القائمة `numbers` التي تم توليدها في خلية الإعداد. استخدم حلقة `for` للمرور على عناصر القائمة وطباعة كل عنصر مع دليله (index). استخدم `enumerate` أو `range(len(...))`.

# %%
# TODO: اطبع كل عنصر من القائمة numbers مع دليله (index)
# مثال: "Index 0: 51"

# %% [markdown]
# ## التكرار بشرط باستخدام `while`
#
# القائمة `numbers` تحتوي على أعداد صحيحة. استخدم حلقة `while` لحساب مجموع الأعداد حتى تصادف عددًا أكبر من 90، ثم توقف. اطبع المجموع الناتج.

# %%
# TODO: استخدم حلقة while لحساب المجموع حتى تجد عدد > 90
# اطبع المجموع

# %% [markdown]
# ## التحكم بالحلقات: `break` و `continue`
#
# لدينا القائمة `names` (تم إنشاؤها في خلية الإعداد). اكتب حلقة `for` تطبع الأسماء التي طولها أكثر من 3 أحرف، وتتخطى الأسماء الأخرى (باستخدام `continue`). إذا صادفت اسم "Khalid"، توقف عن الطباعة تمامًا (باستخدام `break`).

# %%
# TODO: استخدم continue لتخطي الأسماء القصيرة، و break للتوقف عند 'Khalid'

# %% [markdown]
# ## تطبيق: عداد ذكي
#
# لدينا القائمة `numbers`. استخدم حلقة `for` لتنفيذ ما يلي:
# - اجمع الأعداد التي تزيد عن 50.
# - إذا صادفت العدد 42، تجاهله باستخدام `continue`.
# - إذا صادفت عددًا أقل من 10، توقف عن الجمع فورًا باستخدام `break`.
# اطبع المجموع الناتج.

# %%
# TODO: استخدم حلقة for مع continue و break لجمع الأعداد وفق الشروط أعلاه

# %% [markdown]
# ## خلاصة
#
# أحسنت! لقد أكملت تمارين الحلقات التكرارية. تذكر أن الحلقات أدوات قوية لتكرار تنفيذ التعليمة البرمجية وتوفير الوقت والجهد.
