# %% [markdown]
# # مختبر القوائم والعمليات عليها
# في هذا المختبر ستطبق عملياً مفاهيم القوائم (Lists) في بايثون: الإنشاء، الوصول بالفهرس، التقطيع، الإضافة والحذف، والطرق الشائعة. أخيراً ستبني قائمة مهام بسيطة.
#
# ## 1. إنشاء القوائم (List Creation)
# يمكنك إنشاء قائمة بوضع العناصر بين أقواس مربعة `[]`. أنشئ قوائم بالأعداد، النصوص، وقائمة فارغة.

# %%
# TODO: أنشئ قائمة numbers تحتوي الأعداد من 1 إلى 5
numbers = ...
# TODO: أنشئ قائمة fruits تحتوي أسماء ثلاث فواكه
fruits = ...
# TODO: أنشئ قائمة فارغة empty_list
empty_list = ...
# اطبع القوائم للتحقق
print(numbers)
print(fruits)
print(empty_list)

# %% [markdown]
# ## 2. الوصول إلى العناصر بالفهرس (Indexing)
# تذكر أن الفهرس يبدأ من 0. استخدم الفهارس السالبة للوصول من نهاية القائمة.

# %%
# لنفترض أن لدينا القائمة التالية:
my_list = [10, 20, 30, 40, 50]
# TODO: استخدم الفهرس للوصول إلى العنصر الأول وقم بتخزينه في first
first = ...
# TODO: استخدم الفهرس السالب للوصول إلى العنصر الأخير وخزنه في last
last = ...
# TODO: استخدم الفهرس للوصول إلى العنصر الثالث وخزنه في third
third = ...
# اطبع النتائج
print('First:', first)
print('Last:', last)
print('Third:', third)

# %% [markdown]
# ## 3. تقطيع القوائم (Slicing)
# تقطيع القوائم يعطيك جزءاً من القائمة بالصيغة `list[start:stop:step]`. يمكنك حذف الحدود لتضمين البداية أو النهاية.

# %%
# القائمة:
data = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
# TODO: احصل على أول ثلاث عناصر وخزنها في slice1
slice1 = ...
# TODO: احصل على العناصر من الفهرس 2 إلى 5 (غير شامل 5) وخزنها في slice2
slice2 = ...
# TODO: احصل على جميع العناصر بخطوة 2 وخزنها في slice3
slice3 = ...
# TODO: استخدم الفهرسة السالبة لتحصل على آخر عنصرين في slice4
slice4 = ...
# اطبع النتائج
print('slice1:', slice1)
print('slice2:', slice2)
print('slice3:', slice3)
print('slice4:', slice4)

# %% [markdown]
# ## 4. الإضافة: append و insert
# القوائم قابلة للتغيير (mutable)، نضيف عناصر بـ `append()` إلى النهاية، و `insert()` في موضع محدد.

# %%
# ابدأ بقائمة فارغة:
numbers = []
# TODO: أضف العدد 10 إلى نهاية القائمة باستخدام append
...
# TODO: أضف العدد 5 في بداية القائمة (الفهرس 0) باستخدام insert
...
# TODO: أضف 15 في الفهرس 2
...
# اطبع القائمة بعد كل إضافة
print(numbers)

# %% [markdown]
# ## 5. الحذف: remove و pop
# لحذف عناصر: `remove(value)` يحذف أول ظهور للقيمة، و `pop(index)` يحذف ويعيد العنصر في الفهرس (آخر عنصر افتراضياً).

# %%
# قائمة تجريبية:
fruits = ['تفاح', 'موز', 'برتقال', 'موز', 'عنب']
# TODO: احذف أول ظهور للموز باستخدام remove
...
print('بعد remove:', fruits)
# TODO: احذف العنصر في الفهرس 2 باستخدام pop وخزنه في removed
removed = ...
print('العنصر المحذوف:', removed)
print('بعد pop:', fruits)
# TODO: احذف آخر عنصر باستخدام pop بدون معطيات وخزنه في last_removed
last_removed = ...
print('آخر عنصر محذوف:', last_removed)
print('بعد pop الأخير:', fruits)

# %% [markdown]
# ## 6. طرق ودوال شائعة: len, sort, count, in
# ستستخدم `len()` لمعرفة الطول، `.sort()` للترتيب، `.count()` لعد التكرار، والعامل `in` للتحقق من الوجود.

# %%
scores = [5, 2, 8, 3, 8, 1, 9, 8]
# TODO: احصل على طول القائمة (len) وخزنه في length
length = ...
# TODO: رتب القائمة باستخدام sort واطبعها
scores.sort()
print('Sorted:', scores)
# أعد تعريف القائمة لأن sort غيرها
scores = [5, 2, 8, 3, 8, 1, 9, 8]
# TODO: عد مرات ظهور الرقم 8 (count) وخزنه في count_8
count_8 = ...
# TODO: تحقق من وجود الرقم 7 (in) وخزنه في exists
exists = ...
print('Length:', length)
print('Count of 8:', count_8)
print('Is 7 in scores?', exists)

# %% [markdown]
# ## 7. تطبيق: قائمة مهام بسيطة (To-Do List)
# سنبني برنامجاً صغيراً لإدارة المهام باستخدام قائمة ودوال. أكمل الدوال التالية لإضافة مهمة وحذفها وعرض المهام.

# %%
# قائمة المهام الفارغة
tasks = []

def add_task(task):
    # TODO: أضف المهمة إلى القائمة واطبع رسالة تأكيد
    ...

def remove_task(task):
    # TODO: إذا كانت المهمة موجودة، احذفها واطبع رسالة، وإلا اطبع أنها غير موجودة
    ...

def display_tasks():
    # TODO: إذا كانت القائمة فارغة اطبع 'القائمة فارغة'، وإلا اعرض المهام مرقمة
    ...

# تجربة الدوال
add_task('شراء خضار')
add_task('قراءة كتاب')
display_tasks()
remove_task('شراء خضار')
display_tasks()
