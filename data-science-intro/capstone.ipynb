# %% [markdown]
# # مقدمة (Introduction)
# في هذا المشروع الختامي، سنقوم بتحليل استكشافي (Exploratory Data Analysis) لبيانات المدن السعودية. سنستخدم مجموعة بيانات (dataset) تحتوي على معلومات عن المدن، مناطقها، تعدادها السكاني، ومساحاتها. سنستخدم مكتبات pandas و matplotlib لتنفيذ المهام.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# قراءة البيانات
df = pd.read_csv('saudi_cities.csv')

# %% [markdown]
# ## استكشاف البيانات (Data Exploration)
# سنلقي نظرة أولية على البيانات باستخدام الدوال (methods) الأساسية.

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## عدد المدن لكل منطقة (Number of Cities per Region)
# سنحسب عدد المدن التي تنتمي إلى كل منطقة ونعرضها في مخطط شريطي (bar chart).

# %%
# TODO: احسب عدد المدن لكل منطقة وارسم مخططاً شريطياً
# استخدم value_counts على عمود region ثم ارسم مخططاً شريطياً

# %% [markdown]
# ## متوسط السكان لكل منطقة (Average Population per Region)
# سنقوم بتجميع البيانات حسب المنطقة (group by region) وحساب متوسط عدد السكان.

# %%
# TODO: احسب متوسط السكان لكل منطقة
# استخدم groupby('region') على df واحسب المتوسط لعمود population

# %% [markdown]
# ## الكثافة السكانية وأعلى 5 مدن (Population Density and Top 5 Cities)
# سننشئ عموداً جديداً يمثل الكثافة السكانية (ناتج قسمة population على area_km2) ثم نستعرض أعلى 5 مدن من حيث الكثافة.

# %%
# TODO: أنشئ عمود الكثافة السكانية واعرض أعلى 5 مدن
# أنشئ عمود density وقم بترتيب البيانات تنازلياً حسب هذا العمود، ثم اعرض أول 5 صفوف

# %% [markdown]
# ## مخطط مبعثر: السكان مقابل المساحة (Scatter Plot: Population vs Area)
# سنرسم مخططاً مبعثراً (scatter plot) يوضح العلاقة بين تعداد السكان والمساحة.

# %%
# TODO: ارسم مخطط مبعثر للسكان مقابل المساحة
# استخدم plt.scatter مع عمودي population و area_km2

# %% [markdown]
# ## خاتمة (Conclusion)
# من خلال هذا التحليل، تعرفنا على توزيع المدن حسب المناطق، ومتوسطات السكان، والكثافة السكانية. كما لاحظنا العلاقة بين المساحة وتعداد السكان. يمكن توسيع هذا التحليل بإضافة عوامل أخرى.
