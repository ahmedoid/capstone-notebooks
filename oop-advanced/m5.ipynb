# %% [markdown]
# # مشروع نظام إدارة المكتبة
#
# في هذا المختبر، ستقوم ببناء نظام إدارة مكتبة (Library Management System) متكامل باستخدام البرمجة الكائنية. ستطبق مفاهيم الأصناف، التغليف، والاستثناءات.
#
# ستعمل على ثلاث مراحل: بناء صنف `Book`، ثم صنف `Member`، ثم صنف `Library` الذي يدير الكتب والأعضاء. بعد ذلك ستضيف ميزات التغليف والاستثناءات لضمان قوة النظام. وأخيرًا ستختبر النظام باستخدام `assert`.

# %%
from datetime import date, timedelta
from typing import List, Optional

# جميع الاستيرادات اللازمة للمختبر

# %% [markdown]
# ## الجزء 1: بناء صنف الكتاب (Book class)
#
# صنف `Book` يمثل كتابًا بسمات: رقم ISBN، عنوان، مؤلف، سنة النشر، وحالة الإعارة. سنضيف دوالًا سحرية للتهيئة والتمثيل النصي.

# %%
class Book:
    def __init__(self, isbn: str, title: str, author: str, publication_year: int):
        # TODO: قم بتهيئة السمات isbn, title, author, publication_year
        # TODO: أضف السمة is_borrowed واجعلها False افتراضياً
        pass

    def __str__(self) -> str:
        # TODO: ارجع نصاً بالصيغة: "{title} by {author} (ISBN: {isbn})"
        pass

# %% [markdown]
# ## الجزء 2: بناء صنف العضو (Member class)
#
# صنف `Member` يمثل عضوًا في المكتبة، لديه `member_id`، `name`، وقائمة `borrowed_books` لتتبع الكتب المستعارة. يجب إضافة دوال `borrow_book` و `return_book`.

# %%
class Member:
    def __init__(self, member_id: str, name: str):
        # TODO: قم بتهيئة member_id, name, و قائمة borrowed_books فارغة
        pass

    def borrow_book(self, book: Book) -> bool:
        # TODO: تحقق إذا كان الكتاب غير معار، ثم اضفه إلى قائمة العضو وغير حالته إلى True
        # TODO: ارجع True إذا نجحت العملية، وإلا False
        pass

    def return_book(self, book: Book) -> bool:
        # TODO: تحقق إذا كان الكتاب معارًا بواسطة هذا العضو، ثم احذفه من القائمة وغير حالته إلى False
        # TODO: ارجع True إذا نجحت العملية، وإلا False
        pass

# %% [markdown]
# ## الجزء 3: بناء صنف المكتبة (Library class)
#
# صنف `Library` هو القلب النابض، يدير قوائم الكتب والأعضاء، ويوفر دوال للإضافة، البحث، الإعارة، والإرجاع.

# %%
class Library:
    def __init__(self):
        # TODO: قم بإنشاء قائمتين فارغتين: self.books و self.members
        pass

    def add_book(self, book: Book) -> None:
        # TODO: أضف الكتاب إلى self.books
        pass

    def add_member(self, member: Member) -> None:
        # TODO: أضف العضو إلى self.members
        pass

    def find_book_by_isbn(self, isbn: str) -> Optional[Book]:
        # TODO: ابحث عن كتاب برقم ISBN معين، وارجع الكائن أو None
        pass

    def find_member_by_id(self, member_id: str) -> Optional[Member]:
        # TODO: ابحث عن عضو بـ member_id معين، وارجع الكائن أو None
        pass

    def borrow_book(self, isbn: str, member_id: str) -> bool:
        # TODO: ابحث عن الكتاب والعضو، ثم استعر الكتاب للعضو
        # TODO: ارجع True إذا نجحت العملية، وإلا False
        pass

    def return_book(self, isbn: str, member_id: str) -> bool:
        # TODO: ابحث عن الكتاب والعضو، ثم أرجع الكتاب
        # TODO: ارجع True إذا نجحت العملية، وإلا False
        pass

# %% [markdown]
# ## الجزء 4: إضافة التغليف والاستثناءات
#
# لجعل النظام أكثر قوة، سنقوم بـ:
# - جعل سمات الأصناف خاصة (private attributes) مع دوال وصول (getters/setters) عند الحاجة.
# - تعريف استثناءات مخصصة (Custom Exceptions) للإشارة إلى الأخطاء.
# - تعديل دوال مكتبة المكتبة لتقوم برفع هذه الاستثناءات بدلاً من إرجاع False.

# %%
# استثناءات مخصصة
class LibraryError(Exception):
    """الصنف الأساسي لأخطاء المكتبة."""
    pass

class BookNotFoundError(LibraryError):
    """الكتاب غير موجود."""
    pass

class BookAlreadyBorrowedError(LibraryError):
    """الكتاب معار بالفعل."""
    pass

class BookNotBorrowedError(LibraryError):
    """الكتاب ليس معارًا."""
    pass

class BookAlreadyExistsError(LibraryError):
    """الكتاب موجود مسبقاً في المكتبة."""
    pass

class MemberNotFoundError(LibraryError):
    """العضو غير موجود."""
    pass

class MemberAlreadyExistsError(LibraryError):
    """العضو موجود مسبقاً في المكتبة."""
    pass

# %%
# إعادة تعريف Book و Member مع التغليف

class Book:
    def __init__(self, isbn: str, title: str, author: str, publication_year: int):
        # TODO: اجعل جميع السمات خاصة (private) بادئة بـ __
        # وقم بتهيئتها كما سبق، بالإضافة إلى is_borrowed = False
        pass

    # TODO: أضف خواص (properties) للوصول إلى السمات الخاصة
    # مثل @property لـ isbn, title, author, publication_year, is_borrowed (مع setter لـ is_borrowed)

    def __str__(self) -> str:
        # TODO: عدّل ليستخدم السمات الخاصة
        pass


class Member:
    def __init__(self, member_id: str, name: str):
        # TODO: اجعل السمات خاصة: __member_id, __name, __borrowed_books
        pass

    # TODO: أضف خواص للوصول إلى member_id و name (للقراءة فقط)
    # وخاصية للوصول إلى borrowed_books (للقراءة فقط، لكن القائمة قابلة للتعديل)

    def borrow_book(self, book: Book) -> None:
        # TODO: تحقق من أن الكتاب غير معار، ثم استعر (أضف للقائمة، غير is_borrowed إلى True)
        # إذا كان معاراً، ارفع BookAlreadyBorrowedError
        pass

    def return_book(self, book: Book) -> None:
        # TODO: تحقق من أن الكتاب معار لهذا العضو، ثم أرجع (احذف من القائمة، غير is_borrowed إلى False)
        # إذا لم يكن معاراً، ارفع BookNotBorrowedError
        pass

# %%
# إعادة تعريف Library مع معالجة الاستثناءات

class Library:
    def __init__(self):
        # TODO: أنشئ قوائم خاصة: __books, __members
        pass

    @property
    def books(self):
        # TODO: أرجع قائمة الكتب (للقراءة فقط)
        pass

    @property
    def members(self):
        # TODO: أرجع قائمة الأعضاء (للقراءة فقط)
        pass

    def add_book(self, book: Book) -> None:
        # TODO: تحقق إذا كان الكتاب موجوداً مسبقاً (بنفس ISBN) وارفع استثناء إذا كان كذلك
        # وإلا أضفه
        pass

    def add_member(self, member: Member) -> None:
        # TODO: تحقق إذا كان العضو موجوداً مسبقاً (بنفس member_id) وارفع استثناء إذا كان كذلك
        # وإلا أضفه
        pass

    def find_book_by_isbn(self, isbn: str) -> Book:
        # TODO: ابحث عن الكتاب، إذا لم تجده ارفع BookNotFoundError
        pass

    def find_member_by_id(self, member_id: str) -> Member:
        # TODO: ابحث عن العضو، إذا لم تجده ارفع MemberNotFoundError
        pass

    def borrow_book(self, isbn: str, member_id: str) -> None:
        # TODO: ابحث عن الكتاب والعضو، ثم قم بعملية الإعارة عبر استدعاء member.borrow_book
        # قد ترفع استثناءات إذا كان الكتاب معاراً أو غير موجود...
        pass

    def return_book(self, isbn: str, member_id: str) -> None:
        # TODO: ابحث عن الكتاب والعضو، ثم قم بعملية الإرجاع عبر استدعاء member.return_book
        pass

# %% [markdown]
# ## الجزء 5: اختبار النظام
#
# قم بكتابة اختبارات باستخدام `assert` للتحقق من وظائف النظام، بما فيها السيناريوهات الطبيعية والاستثنائية.
#
# الاختبارات المطلوبة:
# - إضافة كتب وأعضاء.
# - إعارة كتاب وإرجاعه بنجاح.
# - محاولة إعارة كتاب غير موجود (استثناء).
# - محاولة إعارة كتاب معار بالفعل.
# - محاولة إرجاع كتاب غير معار.
# - محاولة البحث عن عضو غير موجود.
#
# اكتب تعليمات assert المناسبة.

# %%
# إنشاء مكتبة
lib = Library()

# إنشاء كتب
book1 = Book('978-3-16-148410-0', 'Clean Code', 'Robert C. Martin', 2008)
book2 = Book('978-0-13-235088-4', 'The Pragmatic Programmer', 'Andrew Hunt', 1999)
book3 = Book('978-0-596-51774-8', 'Learning Python', 'Mark Lutz', 2009)

# إنشاء أعضاء
member1 = Member('M001', 'Ahmed')
member2 = Member('M002', 'Sara')

# إضافة إلى المكتبة
lib.add_book(book1)
lib.add_book(book2)
lib.add_book(book3)
lib.add_member(member1)
lib.add_member(member2)

# TODO: اكتب اختبارات assert للسيناريوهات التالية:
# 1. إعارة book1 إلى member1 بنجاح.
# 2. التأكد من أن book1 أصبح معاراً.
# 3. التأكد من أن member1 لديه book1.
# 4. إرجاع book1 بنجاح.
# 5. التأكد من أن book1 لم يعد معاراً.
# 6. محاولة إعارة book1 مرة أخرى إلى member1 (يفترض أن يرمي BookAlreadyBorrowedError)
# 7. محاولة إعارة كتاب برقم ISBN غير موجود (يفترض BookNotFoundError).
# 8. محاولة إرجاع book2 إلى member1 لكن book2 ليس معاراً له (يفترض BookNotBorrowedError).

# أكتب اختبارات assert هنا:

print('جميع الاختبارات نجحت!')

# %% [markdown]
# ## خلاصة
#
# في هذا المختبر، قمت ببناء نظام إدارة مكتبة متكامل مع تغليف واستثناءات. هذا يلخص أهم مفاهيم البرمجة الكائنية. يمكنك توسيع النظام بإضافة ميزات مثل تواريخ الإعارة، الغرامات، أو واجهة مستخدم.
