# %% [markdown]
# # مختبر pandas: أساسيات إطار البيانات
# في هذا المختبر ستقوم بإنشاء إطار بيانات لمدن المملكة العربية السعودية ثم تطبيق دوال الاختيار والتلخيص.

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

cities_ar = ['الرياض', 'جدة', 'مكة', 'المدينة المنورة', 'الدمام', 'الطائف', 'تبوك', 'أبها']
cities_en = ['Riyadh', 'Jeddah', 'Mecca', 'Medina', 'Dammam', 'Taif', 'Tabuk', 'Abha']
population = np.random.randint(500_000, 5_000_000, size=8)

df = pd.DataFrame({
    'city_ar': cities_ar,
    'city_en': cities_en,
    'population': population
})
print('تم إنشاء إطار البيانات بنجاح')

# %% [markdown]
# ## عرض أول 5 صفوف
# نستخدم `df.head()` لعرض أول 5 صفوف من إطار البيانات.

# %%
df.head()

# %% [markdown]
# ## تمرين: عدد المدن
# استخدم الدالة `len()` لمعرفة عدد المدن في إطار البيانات.

# %%
# TODO: احسب عدد المدن باستخدام len(df) وخزنه في المتغير city_count
city_count = ...

# %% [markdown]
# ## اختيار الأعمدة (Column Selection)
# يمكن اختيار عمود واحد باستخدام `df['column']`، وعدة أعمدة باستخدام `df[['col1','col2']]`.

# %%
# TODO: اختر العمود 'city_ar' فقط وخزنه في city_names
city_names = ...

# %%
# TODO: اختر العمودين 'city_ar' و 'population' معًا وخزنه في city_pop
city_pop = ...

# %% [markdown]
# ## دوال التلخيص (Summary Functions)
# يوفر pandas دوالًا مثل `df.shape`، `mean()`، `max()`، `min()`، `sum()`.

# %%
# دوال التلخيص على عمود السكان
print('Shape:', df.shape)
print('Mean population:', df['population'].mean())
print('Max population:', df['population'].max())
print('Min population:', df['population'].min())
print('Sum population:', df['population'].sum())

# %% [markdown]
# ## تمرين: أكبر عدد سكان
# احصل على أكبر قيمة في عمود السكان، وحوّلها إلى عدد صحيح باستخدام `int()`.

# %%
# TODO: احسب أكبر عدد سكان كعدد صحيح وخزنه في max_population
max_population = ...

# %% [markdown]
# ## تمرين: متوسط السكان (كعدد صحيح)
# احسب متوسط السكان، ثم حوّله إلى عدد صحيح.

# %%
# TODO: احسب متوسط السكان كعدد صحيح (int) وخزنه في mean_population
mean_population = ...

# %% [markdown]
# ## خلاصة
# لقد تعلمت كيفية إنشاء إطار بيانات، اختيار الأعمدة، واستخدام دوال التلخيص الأساسية في pandas.
