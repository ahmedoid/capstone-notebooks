# %% [markdown]
# ## المختبر العملي: تحليل البيانات — الترشيح والترتيب والتجميع
#
# في هذا المختبر ستستخدم مكتبة pandas لتحليل بيانات مدن سعودية. ستقوم بالآتي:
# * إنشاء DataFrame يحتوي على أسماء المدن ومناطقها وعدد سكانها.
# * تطبيق عمليات الترشيح، الترتيب، والتجميع للإجابة عن أسئلة محددة.
#
# نفذ الخلايا بالترتيب.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## إعداد البيانات
#
# سنقوم بإنشاء DataFrame من قوائم جاهزة تمثل مدناً سعودية مع مناطقها وعدد سكانها.

# %%
# إنشاء بيانات المدن السعودية
city_ar = ['الرياض', 'جدة', 'مكة', 'المدينة', 'الدمام', 'الطائف', 'تبوك', 'بريدة', 'أبها', 'الهفوف', 'نجران', 'جازان', 'سكاكا', 'الباحة']
region = ['الرياض', 'مكة', 'مكة', 'المدينة', 'الشرقية', 'مكة', 'تبوك', 'القصيم', 'عسير', 'الشرقية', 'نجران', 'جازان', 'الجوف', 'الباحة']
population = [7500000, 4500000, 2000000, 1500000, 1200000, 1100000, 900000, 600000, 500000, 400000, 300000, 200000, 100000, 80000]
df = pd.DataFrame({
    'city_ar': city_ar,
    'region': region,
    'population': population
})
df.head(14)

# %% [markdown]
# ## المهمة 1: الترشيح (Filtering)
#
# اكتب دالة `count_cities_over_million(df)` تُرجع عدد المدن التي يزيد عدد سكانها عن مليون نسمة. استخدم الترشيح بشرط على عمود population.

# %%
def count_cities_over_million(df):
    # TODO: قم بتصفية المدن التي عدد سكانها أكبر من مليون ثم أعد العدد
    pass

# اختبر الدالة
print(count_cities_over_million(df))

# %% [markdown]
# ## المهمة 2: الترتيب (Sorting)
#
# اكتب دالة `largest_city_name(df)` تُرجع اسم المدينة (`city_ar`) صاحبة أكبر عدد سكان. استخدم `sort_values` للترتيب التنازلي.

# %%
def largest_city_name(df):
    # TODO: رتب البيانات تنازليًا حسب السكان وأعد اسم المدينة الأولى
    pass

# اختبر الدالة
print(largest_city_name(df))

# %% [markdown]
# ## المهمة 3: التجميع (Grouping)
#
# اكتب دالة `region_highest_total_population(df)` تُرجع اسم المنطقة التي تمتلك أعلى مجموع سكاني. استخدم `groupby` مع `sum` ثم تعرّف على المنطقة باستخدام `idxmax`.

# %%
def region_highest_total_population(df):
    # TODO: قم بتجميع السكان حسب المنطقة واحصل على مجموع السكان لكل منطقة
    # ثم أعد اسم المنطقة صاحبة أعلى مجموع
    pass

# اختبر الدالة
print(region_highest_total_population(df))

# %% [markdown]
# ## خلاصة
#
# لقد مارست ثلاث عمليات أساسية في تحليل البيانات:
# - **الترشيح**: اختيار صفوف تحقق شرطًا.
# - **الترتيب**: إعادة ترتيب الصفوف حسب عمود.
# - **التجميع**: تقسيم البيانات إلى مجموعات وتطبيق دالة تجميعية.
#
# جرب تعديل الأرقام أو الشروط لترى كيف تتغير النتائج.
