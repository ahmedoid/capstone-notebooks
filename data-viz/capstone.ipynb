# %% [markdown]
# مشروع تحليل بيانات المدن السعودية - في هذا المشروع الختامي، ستقوم بتحليل بيانات 10 مدن سعودية (من ملف 'saudi_cities.csv'). ستتعلم تحميل البيانات، استكشافها، وإنشاء رسوم بيانية (charts) لتوضيح العلاقات بين السكان والمساحة والمناطق.
#
# المتطلبات: أكمل الخلايا التي تحتوي على '# TODO:' لإنشاء الرسوم المطلوبة.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
# قراءة البيانات من ملف CSV
df = pd.read_csv('saudi_cities.csv')

# عرض أول 5 صفوف من البيانات
print('أول 5 صفوف:')
df.head()

# عرض ملخص إحصائي (describe)
print('\nملخص إحصائي:')
df.describe()

# %% [markdown]
# الخطوة 1: رسم بياني بالأعمدة (Bar Chart) لعدد السكان لكل مدينة
#
# قم بترتيب المدن تنازليًا حسب عدد السكان، ثم أنشئ رسمًا بالأعمدة باستخدام matplotlib أو pandas. تأكد من إضافة عنوان، تسمية المحاور، وعرض الرسم.

# %%
# TODO: أنشئ رسمًا بيانيًا بالأعمدة (bar chart) لعدد السكان لكل مدينة مرتبًا تنازليًا.
# استخدم الأعمدة 'city' و 'population'.
# أضف عنوانًا (title) وتسميات المحاور (xlabel, ylabel) واعرض الرسم بـ plt.show().

df_sorted = ...
# قم بإنشاء الشكل هنا
# ...
plt.show()

# %% [markdown]
# الخطوة 2: رسم بياني بالأعمدة لتجمع (Aggregation) السكان حسب المنطقة (Region)
#
# استخدم `groupby('region')` لتجميع البيانات حسب المنطقة وإيجاد مجموع السكان لكل منطقة، ثم ارسم النتائج.

# %%
# TODO: قم بتجميع البيانات حسب العمود 'region' واحسب مجموع السكان لكل منطقة.
# ثم ارسم رسمًا بيانيًا بالأعمدة يوضح مجموع السكان حسب المنطقة.
# استخدم العنوان والتسميات المناسبة.

# قم بتنفيذ التجميع والرسم هنا
# ...
plt.show()

# %% [markdown]
# الخطوة 3: رسم مبعثر (Scatter Plot) للسكان مقابل المساحة
#
# ارسم العلاقة بين عدد السكان (population) والمساحة (area_km2) باستخدام رسم مبعثر. هل تلاحظ أي علاقة؟

# %%
# TODO: أنشئ رسمًا مبعثرًا (scatter plot) لمقارنة عدد السكان والمساحة.
# استخدم الأعمدة 'population' و 'area_km2'.
# أضف عنوانًا وتسميات محاور مناسبة.

# قم بالرسم هنا
# ...
plt.show()

# %% [markdown]
# الخطوة 4 (اختياري): رسم دائري (Pie Chart) لتوزيع السكان حسب المنطقة
#
# لزيادة التصور، يمكنك إنشاء رسم دائري يبين نسبة السكان في كل منطقة.

# %%
# TODO (اختياري): أنشئ رسمًا دائريًا (pie chart) لتوزيع إجمالي السكان حسب المنطقة.
# استخدم التجميع حسب 'region' ومجموع السكان.
# أضف النسب المئوية باستخدام autopct.

# قم بإنشاء الرسم الدائري هنا
# ...
plt.show()

# %% [markdown]
# الخاتمة
#
# أحسنت! لقد قمت بتحميل بيانات المدن السعودية واستكشافها، ثم قمت بإنشاء عدة رسوم بيانية لتصوير العلاقات المختلفة. يمكنك تجربة المزيد من التحليلات أو تحسينات التصميم.
