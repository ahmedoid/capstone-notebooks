# %% [markdown]
# # مختبر البرمجة الكائنية: الأساسيات
# في هذا المختبر، سنطبق المفاهيم الأساسية للبرمجة الكائنية (OOP) في بايثون.
# سنبدأ بفهم الفرق بين البرمجة الإجرائية (Procedural) والبرمجة الكائنية، ثم ننتقل إلى تعريف الأصناف (Classes) وإنشاء الكائنات (Objects).

# %% [markdown]
# ## 1. البرمجة الإجرائية مقابل البرمجة الكائنية
# في البرمجة الإجرائية، نكتب دوالاً (Functions) تتعامل مع بيانات منفصلة. مثال: دالة تحية تاخذ اسماً وتطبع رسالة.

# %%
import numpy as np
np.random.seed(42)  # لضمان تكرار النتائج العشوائية (غير مستخدم هنا لكن للتوافق)
# خلية توضيحية: دالة بسيطة بأسلوب إجرائي
def greet(name):
    print(f'Hello, {name}!')

greet('Ahmed')

# %% [markdown]
# ## 2. الأصناف والكائنات
# في البرمجة الكائنية، نُغلّف البيانات والسلوك داخل أصناف. الصنف (Class) هو قالب، والكائن (Object) هو نموذج من القالب. لنبدأ بتعريف صنف بسيط.

# %%
# TODO: قم بتعريف صنف (Class) اسمه 'Greeter' بداخله طريقة (Method) اسمها 'greet' تطبع تحية.
# ثم أنشئ كائناً من هذا الصنف واستدعِ الطريقة.

# اكتب الكود الخاص بك هنا:

class Greeter:
    def greet(self, name):
        # TODO: اكمل التنفيذ
        pass

# إنشاء كائن واختباره
g = Greeter()
g.greet('Ahmed')

# %% [markdown]
# ## 3. المنشئ __init__
# المنشئ (Constructor) هو دالة خاصة تنفذ عند إنشاء كائن جديد، نستخدمها لتهيئة سمات (Attributes) الكائن. في بايثون، اسمه `__init__`.

# %%
# TODO: أضف دالة __init__ للصنف Person لتأخذ اسم الشخص (name) وتخزنه كسمة (attribute).
class Person:
    # TODO: اكتب __init__ هنا
    pass

p = Person('Ahmed')
print(p.name)  # يجب أن يطبع 'Ahmed'

# %% [markdown]
# ## 4. الوسيط self
# `self` يمثل الكائن الحالي داخل الصنف، ويستخدم للوصول إلى سمات وطرق الكائن. يجب أن يكون أول وسيط في أي طريقة داخل الصنف.

# %%
# TODO: أكمل الكود التالي بإضافة self في الأماكن المناسبة لجعل الصنف يعمل.
class Counter:
    def __init__():
        self.count = 0

    def increment():
        self.count += 1

    def get_count():
        return self.count

c = Counter()
c.increment()
c.increment()
print(c.get_count())  # يجب أن يطبع 2

# %% [markdown]
# ## 5. مشروع: صنف الطالب (Student Class)
# الآن، ستقوم ببناء صنف `Student` يحتوي على السمات: الاسم (`name`) والعمر (`age`)، ويحتوي على طريقة `display_info` تعرض معلومات الطالب.

# %%
# TODO: قم بتعريف صنف Student مع:
# - دالة __init__ تأخذ name و age وتخزنهما.
# - طريقة display_info تطبع المعلومات.
class Student:
    # TODO: اكتب الكود هنا
    pass

# %% [markdown]
# ## 6. اختبار صنف الطالب
# الآن، قم بإنشاء بعض كائنات الطلاب واستخدم الطريقة لعرض معلوماتهم.

# %%
# TODO: أنشئ كائنين من Student (بأسماء وأعمار من اختيارك) واطبع معلوماتهما باستخدام display_info.
# مثال:
# student1 = Student('Ali', 20)
# student1.display_info()

# اكتب الكود هنا:
student1 = Student('Ali', 20)
# TODO: أضف كائناً آخر واطبع معلوماته

# %% [markdown]
# ## خلاصة
# في هذا المختبر، تعلمنا:
# - الفرق بين البرمجة الإجرائية والكائنية.
# - كيفية تعريف صنف بسيط وطرقه.
# - استخدام المنشئ `__init__` لتهيئة الكائنات.
# - دور `self` في الوصول إلى سمات الكائن.
# - بناء صنف كامل `Student` يمثل كياناً من العالم الحقيقي.
