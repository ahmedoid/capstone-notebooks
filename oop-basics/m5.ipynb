# %% [markdown]
# # الطرق السحرية في بايثون
# في هذا المختبر سنختبر كيف تتحكم الطرق السحرية في سلوك الكائنات عند الطباعة والمقارنة والعمليات الحسابية.

# %%
# استكشاف الطرق السحرية (Magic Methods) في أنواع البيانات المضمنة
print(dir(list))
# لاحظ الطرق التي تبدأ وتنتهي بشرطتين سفليتين مثل __len__, __getitem__, __add__

# %% [markdown]
# ## التمرين 1: صنف Book
# أنشئ صنف `Book` يحتوي على عنوان (`title`) ومؤلف (`author`).
# قم بتطبيق الطرق التالية:
# - `__str__`: ترجع سلسلة نصية بالشكل `Title: {title}, Author: {author}`.
# - `__repr__`: ترجع سلسلة بالشكل `Book('{title}', '{author}')` يمكن استخدامها لإعادة إنشاء الكائن.
# - `__eq__`: تحدد متى يتساوى كتابان (بناءً على تطابق العنوان والمؤلف).

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    # TODO: أكمل دالة __str__ لإرجاع السلسلة 'Title: {title}, Author: {author}'
    def __str__(self):
        return ""  # TODO: replace with proper string

    # TODO: أكمل دالة __repr__ لإرجاع السلسلة "Book('{title}', '{author}')"
    def __repr__(self):
        return ""  # TODO: replace

    # TODO: أكمل دالة __eq__ بحيث يعتبر الكتابان متساويين إذا تطابق title و author
    def __eq__(self, other):
        pass  # TODO: return comparison result

# %% [markdown]
# ## التمرين 2: صنف Vector2D
# سننشئ صنف `Vector2D` لمتجهات ثنائية الأبعاد. قم بتنفيذ:
# - `__init__`: تستقبل x و y.
# - `__str__`: ترجع `Vector2D({x}, {y})`.
# - `__repr__`: ترجع `Vector2D({x}, {y})`.

# %%
import math

class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # TODO: أكمل __str__ بإرجاع السلسلة بتنسيق Vector2D({x}, {y})
    def __str__(self):
        return ""  # TODO

    # TODO: أكمل __repr__ بنفس التنسيق
    def __repr__(self):
        return ""  # TODO

# %% [markdown]
# ## التمرين 3: توسيع Vector2D بالعمليات
# أضف إلى صنف `Vector2D` الطرق التالية:
# - `__add__`: تجمع متجهين وتعيد متجهًا جديدًا مجموع مركباتهما.
# - `__eq__`: تتحقق من تساوي المتجهين (تطابق x و y).
# - `__abs__`: تحسب الطول (المسافة الإقليدية) باستخدام `math.hypot` أو `sqrt`.

# %%
import math

class Vector2D:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __str__(self):
        return f"Vector2D({self.x}, {self.y})"

    def __repr__(self):
        return f"Vector2D({self.x}, {self.y})"

    # TODO: أكمل __add__ لإرجاع Vector2D جديد مجموع المركبات
    def __add__(self, other):
        pass  # TODO

    # TODO: أكمل __eq__ لتساوي المتجهات إذا تساوت مركباتها
    def __eq__(self, other):
        pass  # TODO

    # TODO: أكمل __abs__ لإرجاع طول المتجه
    def __abs__(self):
        pass  # TODO

# %% [markdown]
# ## التمرين 4: صنف NumberList
# صمم صنف `NumberList` يغلف قائمة أعداد، ويوفر:
# - `__len__`: يرجع عدد العناصر.
# - `__getitem__`: يرجع العنصر في الفهرس المحدد.

# %%
class NumberList:
    def __init__(self, numbers):
        self.numbers = numbers

    # TODO: أكمل __len__ لإرجاع عدد العناصر
    def __len__(self):
        pass  # TODO

    # TODO: أكمل __getitem__ لإرجاع العنصر في الفهرس المطلوب
    def __getitem__(self, index):
        pass  # TODO

# %% [markdown]
# ## اختبر مهاراتك
# اكتب كودًا في الخلية التالية لاختبار الأصناف التي أنشأتها. قم بما يلي:
# - أنشئ كتابين واختبر __str__ و __repr__ و __eq__.
# - أنشئ متجهين واجمعهما واطبع الناتج، واحسب الطول.
# - أنشئ NumberList وجرب len و indexing.

# %%
# اكتب كود الاختبار هنا

# %% [markdown]
# ## خلاصة
# لقد تعلمت كيف تتحكم في تمثيل الكائنات ومقارنتها وجعلها تتصرف كأنواع مضمنة عبر الطرق السحرية. تعتبر هذه الأدوات أساسية في كتابة كود نظيف ومعبر في بايثون.
